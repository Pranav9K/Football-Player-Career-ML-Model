# %% [markdown]
# Football Player Future G/A Predictor

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df23 = pd.read_csv('football-data_23-24.csv') 
df24 = pd.read_csv('football-data_24-25.csv')
df25 = pd.read_csv('football-data_25-26.csv')
